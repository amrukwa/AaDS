# %% [markdown]
# Anna Mrukwa
# Makrokierunek sem.5

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from time import time
pd.set_option('display.float_format', '{:.4E}'.format)
pd.options.display.max_colwidth = 100

# %% [markdown]
# # LCS algorithm

# %% [markdown]
# ### Path table:
# 0 - do nothing
# 1 - go up
# 2 - go left
# 3 - go up-left

# %%
def LCS_rec(word1, word2):
  t0 = time()
  if len(word1) == 0 or len(word2) == 0:
    return 0, time()-t0
  if word1[len(word1)-1] == word2[len(word2)-1]:
    res, _ = LCS_rec(word1[:-1], word2[:-1])
    return res+1, time()-t0
  res1, _ = LCS_rec(word1[:], word2[:-1])
  res2, _ = LCS_rec(word1[:-1], word2[:])
  return max(res1, res2), time()-t0

# %%
def LCS_DP(word1, word2):
  ncols = len(word2)+1
  nrows = len(word1)+1
  t0 = time()
  lcs_table = np.zeros((nrows, ncols), dtype=int)
  path_table = np.zeros((nrows, ncols), dtype=int)
  for i in range(1, nrows):
    for j in range(1, ncols):
      if word1[i-1] == word2[j-1]:
        lcs_table[i, j] = lcs_table[i-1, j-1] + 1
        path_table[i, j] = 3
      else:
        if lcs_table[i-1, j] >= lcs_table[i, j-1]:
          lcs_table[i, j] = lcs_table[i-1, j]
          path_table[i, j] = 1
        else:
          lcs_table[i, j] = lcs_table[i, j-1]
          path_table[i, j] = 2
  LCS = lcs_table[-1, -1]
  return LCS, path_table, time()-t0

# %%
def print_LCS(path_table, word1): 
  # this one is with longer word for LITE or the first one put in normal ver.
  LCS = ""
  nrows = path_table.shape[0] - 1
  ncols = path_table.shape[1] - 1
  while nrows >= 0 and ncols >= 0:
    if path_table[nrows, ncols] == 3: # go diagonally
      LCS = word1[nrows-1] + LCS # because of 0 in the algorithm
      nrows -= 1
      ncols -= 1
    elif path_table[nrows, ncols] == 2: # go left
      ncols -= 1
    else: # go up
      nrows -= 1
  return LCS

# %% [markdown]
# # Edit distance

# %% [markdown]
# ### Change table:
# 0 - do nothing
# 1 - go up
# 2 - go left
# 3 - go up-left

# %%
def insert_cost(dist_type):
  if dist_type=='Levenshtein' or dist_type=='LCS':
    return 1

def del_cost(dist_type):
  if dist_type=='Levenshtein' or dist_type=='LCS':
    return 1

def repl_cost(letter1, letter2, dist_type):
  if letter1==letter2:
    return 0
  if dist_type=='Levenshtein':
    return 1
  if dist_type=='LCS':
    return np.Inf

# %%
def ED_rec(word1, word2, dist_type='Levenshtein'):
  t0 = time()
  if len(word1) == 0: # inserting all the characters
    return len(word2)*insert_cost(dist_type=dist_type), time()-t0
  if len(word2) == 0: # deleting all the characters
     return len(word1)*del_cost(dist_type=dist_type), time()-t0
  if word1[len(word1)-1] == word2[len(word2)-1]: # last characters are the same
    res, _ = ED_rec(word1[:-1], word2[:-1], dist_type=dist_type)
    return res, time()-t0
  # if not the same, do the least costly operation from:
  # insertion
  res_ins, _ = ED_rec(word1[:], word2[:-1], dist_type=dist_type)
  res_ins += insert_cost(dist_type=dist_type)
  # deletion
  res_del, _ = ED_rec(word1[:-1], word2[:], dist_type=dist_type)
  res_del += del_cost(dist_type=dist_type)
  # replacement
  res_rep, _ = ED_rec(word1[:-1], word2[:-1], dist_type=dist_type)
  res_rep += repl_cost(word1[-1], word2[-1], dist_type=dist_type)

  ED = min(res_ins, res_rep, res_del)
  return ED, time()-t0

# %%
def ED_DP(word1, word2, dist_type='Levenshtein'):
  ncols = len(word2)+1
  nrows = len(word1)+1
  t0 = time()
  ed_table = np.zeros((nrows, ncols), dtype=int)
  change_table = np.zeros((nrows, ncols), dtype=int)

  for i in range(1, nrows):
    ed_table[i, 0] = i*del_cost(dist_type=dist_type)
    change_table[i, 0] = 1
  for j in range(1, ncols):
    ed_table[0, j] = j*insert_cost(dist_type=dist_type)
    change_table[0, j] = 2

  for i in range(1, nrows):
    for j in range(1, ncols):
      deletion_cost = ed_table[i-1, j] + del_cost(dist_type=dist_type)
      insertion_cost = ed_table[i, j-1] + insert_cost(dist_type=dist_type)
      replacement_cost = ed_table[i-1, j-1] + repl_cost(word1[i-1], word2[j-1], dist_type=dist_type)
      # del, insert, repl
      operations = np.array([deletion_cost, insertion_cost, replacement_cost])
      op = np.argmin(operations)
      ed_table[i,j] = operations[op]
      change_table[i,j] = op+1
  ED = ed_table[-1, -1]
  return ED, change_table, time()-t0

# %%
def print_operations(path_table, word1, word2):

  operations = ""
  nrows = path_table.shape[0] - 1
  ncols = path_table.shape[1] - 1
  while nrows >= 0 and ncols >= 0:
    if path_table[nrows, ncols] == 3: # go diagonally
      # LCS = word1[nrows-1] + LCS # because of 0 in the algorithm
      nrows -= 1
      ncols -= 1
      if word1[nrows] == word2[ncols]:
        operations = word2[ncols] + " " + operations
      else:
        operations = "rep("+word1[nrows]+ ","+ word2[ncols] + ") " + operations
    elif path_table[nrows, ncols] == 2: # go left - insertion
      ncols -= 1
      operations = "ins("+ word2[ncols] + ") " + operations
    elif path_table[nrows, ncols] == 1: # go up - deletion
      nrows -= 1
      operations = "del("+ word1[nrows] + ") " + operations
    else:
      return operations[:-1]
  return operations[:-1]

  return 0

# %% [markdown]
# # Testing

# %% [markdown]
# ## LCS

# %%
LCS_strings1 = ["ABCDGH", "AGGTAB", "ABCBDAB", "XMJYAUZ", "ABDTTTTTTT", "WORD1", '', 'CONSEQUENCE', '', 'ABCDEFG', 'QWERTY', "WORD1"]
LCS_strings2 = ["AEDFHR", "GXTXAYB", "BDCABA", "MZJAWXU", "ZNCXMVZNXM", '', 'WORD2', 'CONSISTENCE', '', 'ABCDEFG', 'YTREWQ', 'WORD2']

colnames = ['STRING A', 'STRING B', 'LENGTH OF LCS', 'LCS', 
            'Times for DP ver.', 'Times for recursive ver.']
LCS_lens = []
found_LCS = []
DP_times = []
rec_times = []

# %%
for i in tqdm(range(len(LCS_strings1))):
  str1 = LCS_strings1[i]
  str2 = LCS_strings2[i]
  # DP
  LCS_len1, pt, t = LCS_DP(str1, str2)
  LCS_lens.append(LCS_len1)
  DP_times.append(t)
  LCS1 = print_LCS(pt, str1)
  found_LCS.append(LCS1)
  # REC
  LCS_len3, t = LCS_rec(str1, str2)
  assert LCS_len3 == LCS_len1
  rec_times.append(t)
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 35.06it/s]

# %%
df = pd.DataFrame(list(zip(LCS_strings1, LCS_strings2, LCS_lens, found_LCS, 
                           DP_times, rec_times)),
               columns=colnames)
df
# Out:
#        STRING A     STRING B  LENGTH OF LCS       LCS  Times for DP ver.  \
# 0        ABCDGH       AEDFHR              3       ADH         1.5140E-04
# 1        AGGTAB      GXTXAYB              4      GTAB         8.9169E-05
# 2       ABCBDAB       BDCABA              4      BCBA         8.1301E-05
# 3       XMJYAUZ      MZJAWXU              4      MJAU         8.8453E-05
# 4    ABDTTTTTTT   ZNCXMVZNXM              0                   1.0967E-04
# 5         WORD1                           0                   1.7166E-05
# 6                      WORD2              0                   1.9073E-06
# 7   CONSEQUENCE  CONSISTENCE              8  CONSENCE         1.6332E-04
# 8                                         0                   1.0014E-05
# 9       ABCDEFG      ABCDEFG              7   ABCDEFG         5.3644E-05
# 10       QWERTY       YTREWQ              1         Q         7.1764E-05
# 11        WORD1        WORD2              4      WORD         7.7486E-05
#
#     Times for recursive ver.
# 0                 1.0519E-03
# 1                 4.9710E-04
# 2                 2.1100E-04
# 3                 2.3642E-03
# 4                 3.3233E-01
# 5                 4.7684E-07
# 6                 2.3842E-07
# 7                 1.8802E-03
# 8                 4.7684E-07
# 9                 7.6294E-06
# 10                9.1577E-04
# 11                2.0432E-04

# %% [markdown]
# ## ED

# %%
ED_strings1 = ["INTENTION", "SUNDAY", "CART", "QUARANTINE", "INDUSTRY", 'WORD1', '', 'QWERTY', '', 'ABCDEFG', 'VISUALIZATION', 'WORD1']
ED_strings2 = ["EXECUTION", "SATURDAY", "MARCH", "RUNTIME", 'INTEREST', '', 'WORD2', 'YTREWQ','', 'ABCDEFG', 'QUALIFICATION', 'WORD2']
colnames = ['STRING A', 'STRING B', 'ED', 'Operations', 
            'Times for DP ver.', 'Times for recursive ver.']

# %% [markdown]
# ### Levenshtein distance

# %%
dist_type='Levenshtein'
found_ED = []
operations = []
DP_times = []
rec_times = []

# %%
for i in tqdm(range(len(ED_strings1))):
  str1 = ED_strings1[i]
  str2 = ED_strings2[i]
  # DP
  ED1, pt1, t = ED_DP(str1, str2, dist_type)
  found_ED.append(ED1)
  DP_times.append(t)
  ops = print_operations(pt1, str1, str2)
  operations.append(ops)
  # REC
  ED3, t = ED_rec(str1, str2, dist_type)
  assert ED3 == ED1
  rec_times.append(t)
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 36.35it/s]

# %%
df = pd.DataFrame(list(zip(ED_strings1, ED_strings2, found_ED, operations, 
                           DP_times, rec_times)),
               columns=colnames)
df
# Out:
#          STRING A       STRING B  ED  \
# 0       INTENTION      EXECUTION   5
# 1          SUNDAY       SATURDAY   3
# 2            CART          MARCH   3
# 3      QUARANTINE        RUNTIME   5
# 4        INDUSTRY       INTEREST   6
# 5           WORD1                  5
# 6                          WORD2   5
# 7          QWERTY         YTREWQ   6
# 8                                  0
# 9         ABCDEFG        ABCDEFG   0
# 10  VISUALIZATION  QUALIFICATION   6
# 11          WORD1          WORD2   1
#
#                                                          Operations  \
# 0                rep(I,E) rep(N,X) del(T) E rep(N,C) ins(U) T I O N
# 1                                  S ins(A) ins(T) U rep(N,R) D A Y
# 2                                      rep(C,M) A R rep(T,C) ins(H)
# 3                  rep(Q,R) U del(A) del(R) del(A) N T I rep(N,M) E
# 4             I N rep(D,T) rep(U,E) ins(R) ins(E) S T del(R) del(Y)
# 5                                del(W) del(O) del(R) del(D) del(1)
# 6                                ins(W) ins(O) ins(R) ins(D) ins(2)
# 7               rep(Q,Y) rep(W,T) ins(R) E rep(R,W) rep(T,Q) del(Y)
# 8
# 9                                                     A B C D E F G
# 10  rep(V,Q) del(I) del(S) U A L I rep(Z,F) ins(I) ins(C) A T I O N
# 11                                                 W O R D rep(1,2)
#
#     Times for DP ver.  Times for recursive ver.
# 0          1.2784E-03                1.8647E-03
# 1          7.6461E-04                2.0862E-04
# 2          4.0245E-04                5.1475E-04
# 3          1.0915E-03                2.3792E-02
# 4          1.0018E-03                1.5407E-01
# 5          2.4557E-05                7.1526E-07
# 6          5.0068E-06                4.7684E-07
# 7          6.3014E-04                6.7577E-03
# 8          1.7405E-05                1.4305E-06
# 9          1.4493E-03                9.2983E-06
# 10         9.6250E-04                1.2945E-01
# 11         4.6802E-04                8.8501E-04

# %% [markdown]
# ### LCS distance

# %%
dist_type='LCS'
found_ED = []
operations = []
DP_times = []
rec_times = []

# %%
for i in tqdm(range(len(ED_strings1))):
  str1 = ED_strings1[i]
  str2 = ED_strings2[i]
  # DP
  ED1, pt1, t = ED_DP(str1, str2, dist_type)
  found_ED.append(ED1)
  DP_times.append(t)
  ops = print_operations(pt1, str1, str2)
  operations.append(ops)
  # REC
  ED3, t = ED_rec(str1, str2, dist_type)
  assert ED3 == ED1
  rec_times.append(t)
# Out:
# 100%|██████████| 12/12 [00:00<00:00, 35.16it/s]

# %%
df = pd.DataFrame(list(zip(ED_strings1, ED_strings2, found_ED, operations, 
                           DP_times, rec_times)),
               columns=colnames)
df
# Out:
#          STRING A       STRING B  ED  \
# 0       INTENTION      EXECUTION   8
# 1          SUNDAY       SATURDAY   4
# 2            CART          MARCH   5
# 3      QUARANTINE        RUNTIME   7
# 4        INDUSTRY       INTEREST   8
# 5           WORD1                  5
# 6                          WORD2   5
# 7          QWERTY         YTREWQ  10
# 8                                  0
# 9         ABCDEFG        ABCDEFG   0
# 10  VISUALIZATION  QUALIFICATION   8
# 11          WORD1          WORD2   2
#
#                                                                    Operations  \
# 0           del(I) del(N) del(T) E ins(X) ins(E) ins(C) ins(U) del(N) T I O N
# 1                                       S ins(A) ins(T) U ins(R) del(N) D A Y
# 2                                      ins(M) del(C) A R ins(C) ins(H) del(T)
# 3                  ins(R) del(Q) U del(A) del(R) del(A) N T I ins(M) del(N) E
# 4             I N ins(T) ins(E) ins(R) ins(E) del(D) del(U) S T del(R) del(Y)
# 5                                          del(W) del(O) del(R) del(D) del(1)
# 6                                          ins(W) ins(O) ins(R) ins(D) ins(2)
# 7     ins(Y) ins(T) ins(R) ins(E) ins(W) Q del(W) del(E) del(R) del(T) del(Y)
# 8
# 9                                                               A B C D E F G
# 10  ins(Q) del(V) del(I) del(S) U A L I ins(F) ins(I) ins(C) del(Z) A T I O N
# 11                                                      W O R D ins(2) del(1)
#
#     Times for DP ver.  Times for recursive ver.
# 0          1.3468E-03                4.9264E-03
# 1          8.2135E-04                4.5180E-04
# 2          2.2984E-04                4.6062E-04
# 3          5.9676E-04                2.9205E-02
# 4          1.4324E-03                1.4863E-01
# 5          2.6941E-05                9.5367E-07
# 6          8.8215E-06                7.1526E-07
# 7          5.9438E-04                6.6938E-03
# 8          1.3828E-05                4.7684E-07
# 9          4.6539E-04                2.0266E-05
# 10         1.3463E-03                1.3911E-01
# 11         5.8436E-04                5.4264E-04
